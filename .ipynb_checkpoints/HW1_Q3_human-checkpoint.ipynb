# %%
import numpy as np

feature = []
label = []

with open('/Users/songchenyu/Downloads/human+activity+recognition+using+smartphones/UCI HAR Dataset/train/X_train.txt', 'r') as file:
    for line in file:
        # 使用空格分割行
        words = line.split()
        feature.append(words)
        
with open('/Users/songchenyu/Downloads/human+activity+recognition+using+smartphones/UCI HAR Dataset/test/X_test.txt', 'r') as file:
    for line in file:
        # 使用空格分割行
        words = line.split()
        feature.append(words)


        
with open('/Users/songchenyu/Downloads/human+activity+recognition+using+smartphones/UCI HAR Dataset/train/y_train.txt', 'r') as file:
    for line in file:
        # 使用空格分割行
        words = line.split()
        label.append(words[0])
        
with open('/Users/songchenyu/Downloads/human+activity+recognition+using+smartphones/UCI HAR Dataset/test/y_test.txt', 'r') as file:
    for line in file:
        # 使用空格分割行
        words = line.split()
        label.append(words[0])

# print(np.array(feature).shape)
# print(np.array(label).shape)

# %%
import pandas as pd

combined_list = [a + [b] for a, b in zip(feature, label)]
#combined_list = [(a, b) for a, b in zip(feature, label)]

df = pd.DataFrame(combined_list)
print(df.head())
df = df.apply(pd.to_numeric, errors='coerce')
# Out:
#               0                1                2                3    \
# 0  2.8858451e-001  -2.0294171e-002  -1.3290514e-001  -9.9527860e-001
# 1  2.7841883e-001  -1.6410568e-002  -1.2352019e-001  -9.9824528e-001
# 2  2.7965306e-001  -1.9467156e-002  -1.1346169e-001  -9.9537956e-001
# 3  2.7917394e-001  -2.6200646e-002  -1.2328257e-001  -9.9609149e-001
# 4  2.7662877e-001  -1.6569655e-002  -1.1536185e-001  -9.9813862e-001
#
#                4                5                6                7    \
# 0  -9.8311061e-001  -9.1352645e-001  -9.9511208e-001  -9.8318457e-001
# 1  -9.7530022e-001  -9.6032199e-001  -9.9880719e-001  -9.7491437e-001
# 2  -9.6718701e-001  -9.7894396e-001  -9.9651994e-001  -9.6366837e-001
# 3  -9.8340270e-001  -9.9067510e-001  -9.9709947e-001  -9.8274984e-001
# 4  -9.8081727e-001  -9.9048163e-001  -9.9832113e-001  -9.7967187e-001
#
#                8                9    ...              552              553  \
# 0  -9.2352702e-001  -9.3472378e-001  ...  -2.9867637e-001  -7.1030407e-001
# 1  -9.5768622e-001  -9.4306751e-001  ...  -5.9505094e-001  -8.6149931e-001
# 2  -9.7746859e-001  -9.3869155e-001  ...  -3.9074815e-001  -7.6010372e-001
# 3  -9.8930250e-001  -9.3869155e-001  ...  -1.1729020e-001  -4.8284451e-001
# 4  -9.9044113e-001  -9.4246912e-001  ...  -3.5147093e-001  -6.9920515e-001
#
#                554              555              556              557  \
# 0  -1.1275434e-001   3.0400372e-002  -4.6476139e-001  -1.8445884e-002
# 1   5.3476955e-002  -7.4345661e-003  -7.3262621e-001   7.0351059e-001
# 2  -1.1855926e-001   1.7789948e-001   1.0069921e-001   8.0852908e-001
# 3  -3.6787973e-002  -1.2892494e-002   6.4001104e-001  -4.8536645e-001
# 4   1.2332005e-001   1.2254196e-001   6.9357829e-001  -6.1597061e-001
#
#                558             559              560 561
# 0  -8.4124676e-001  1.7994061e-001  -5.8626924e-002   5
# 1  -8.4478760e-001  1.8028889e-001  -5.4316717e-002   5
# 2  -8.4893347e-001  1.8063731e-001  -4.9117815e-002   5
# 3  -8.4864938e-001  1.8193476e-001  -4.7663183e-002   5
# 4  -8.4786525e-001  1.8515116e-001  -4.3892254e-002   5
#
# [5 rows x 562 columns]

# %%
import pandas as pd
import numpy as np


# 获取类别标签
class_labels=[1,2,3,4,5,6]
print("class_lables:",class_labels)

data=df
N = len(data)
p = [] ##先验概率
N_samples = [] ##各类样本数



# 初始化一个字典，用于存储每个类别的均值向量、协方差矩阵和样本数量
class_stats = {}

for label in class_labels:
    # 按类别筛选数据
    
    
    class_data = data[data[561] == label]
    
    # 提取特征列
    features = class_data.iloc[:, :-1]

    
    # 计算均值向量
    mean_vector = np.mean(features, axis=0)
    print(mean_vector)
    
     # 计算协方差矩阵
    lambda_ = 0.01  # 正则化参数
    I = np.identity(features.shape[1])  # 单位矩阵
    cov_matrix = np.cov(features, rowvar=False) + lambda_ * I
   
    #cov_matrix = np.cov(features, rowvar=False)
    
    # 统计样本数量
    num_samples = len(class_data)
    
    # 存储类别统计信息
    class_stats[label] = {
        'mean_vector': mean_vector,
        'cov_matrix': cov_matrix,
        'num_samples': num_samples
    }

# 打印每个类别的统计信息
for label, stats in class_stats.items():
    print(f"Class {label}:")
    print("Mean Vector:")
    print(stats['mean_vector'])
    print("Covariance Matrix:")
    print(stats['cov_matrix'])
    print(f"Number of Samples: {stats['num_samples']}")
    print()
# Out:
# class_lables: [1, 2, 3, 4, 5, 6]
# 0      0.276337
# 1     -0.017907
# 2     -0.108882
# 3     -0.314644
# 4     -0.023583
#          ...
# 556    0.011332
# 557   -0.019443
# 558   -0.761886
# 559    0.218599
# 560    0.059771
# Length: 561, dtype: float64
# 0      0.262295
# 1     -0.025923
# 2     -0.120538
# 3     -0.237990
# 4     -0.016033
#          ...
# 556   -0.129903
# 557    0.036432
# 558   -0.637980
# 559    0.278642
# 560    0.122794
# Length: 561, dtype: float64
# 0      0.288137
# 1     -0.016312
# 2     -0.105762
# 3      0.100766
# 4      0.059549
#          ...
# 556    0.203588
# 557   -0.076029
# 558   -0.780873
# 559    0.200189
# 560    0.055866
# Length: 561, dtype: float64
# 0      0.273060
# 1     -0.012690
# 2     -0.105517
# 3     -0.983446
# 4     -0.934881
#          ...
# 556    0.013413
# 557   -0.033260
# 558   -0.706042
# 559    0.006140
# 560   -0.089532
# Length: 561, dtype: float64
# 0      0.279153
# 1     -0.016152
# 2     -0.106587
# 3     -0.984435
# 4     -0.932509
#          ...
# 556    0.004614
# 557    0.015957
# 558   -0.774143
# 559    0.209818
# 560    0.031743
# Length: 561, dtype: float64
# 0      0.268649
# 1     -0.018318
# 2     -0.107436
# 3     -0.960932
# 4     -0.943507
#          ...
# 556    0.022788
# 557    0.009191
# 558    0.520261
# 559   -0.435944
# 560   -0.427749
# Length: 561, dtype: float64
# Class 1:
# Mean Vector:
# 0      0.276337
# 1     -0.017907
# 2     -0.108882
# 3     -0.314644
# 4     -0.023583
#          ...
# 556    0.011332
# 557   -0.019443
# 558   -0.761886
# 559    0.218599
# 560    0.059771
# Length: 561, dtype: float64
# Covariance Matrix:
# [[ 1.24461291e-02  9.11530670e-06 -1.29152685e-04 ... -5.27339859e-05
#   -2.28929354e-05 -1.16936019e-04]
#  [ 9.11530670e-06  1.04222265e-02  9.18078107e-05 ... -2.04621790e-05
#    1.97661936e-05 -9.03647580e-05]
#  [-1.29152685e-04  9.18078107e-05  1.10108531e-02 ...  2.74001744e-05
#    5.12017661e-05  6.70252537e-05]
#  ...
#  [-5.27339859e-05 -2.04621790e-05  2.74001744e-05 ...  1.97359988e-02
#    4.24589363e-03  6.17854887e-03]
#  [-2.28929354e-05  1.97661936e-05  5.12017661e-05 ...  4.24589363e-03
#    1.43626291e-02  1.01160048e-03]
#  [-1.16936019e-04 -9.03647580e-05  6.70252537e-05 ...  6.17854887e-03
#    1.01160048e-03  2.18880764e-02]]
# Number of Samples: 1722
#
# Class 2:
# Mean Vector:
# 0      0.262295
# 1     -0.025923
# 2     -0.120538
# 3     -0.237990
# 4     -0.016033
#          ...
# 556   -0.129903
# 557    0.036432
# 558   -0.637980
# 559    0.278642
# 560    0.122794
# Length: 561, dtype: float64
# Covariance Matrix:
# [[ 1.57600608e-02  6.95849525e-04  4.98064723e-04 ...  2.72798700e-05
#    1.65681022e-04 -5.26365746e-04]
#  [ 6.95849525e-04  1.13715544e-02  2.69124480e-04 ...  6.31727205e-04
#    1.15227373e-04  4.10500307e-04]
#  [ 4.98064723e-04  2.69124480e-04  1.33812638e-02 ...  1.41648262e-04
#    3.09544679e-04 -9.70294679e-05]
#  ...
#  [ 2.72798700e-05  6.31727205e-04  1.41648262e-04 ...  2.51151294e-02
#    4.31473756e-03  1.30095188e-02]
#  [ 1.65681022e-04  1.15227373e-04  3.09544679e-04 ...  4.31473756e-03
#    1.71970644e-02 -6.54192933e-04]
#  [-5.26365746e-04  4.10500307e-04 -9.70294679e-05 ...  1.30095188e-02
#   -6.54192933e-04  2.98358098e-02]]
# Number of Samples: 1544
#
# Class 3:
# Mean Vector:
# 0      0.288137
# 1     -0.016312
# 2     -0.105762
# 3      0.100766
# 4      0.059549
#          ...
# 556    0.203588
# 557   -0.076029
# 558   -0.780873
# 559    0.200189
# 560    0.055866
# Length: 561, dtype: float64
# Covariance Matrix:
# [[ 1.82813779e-02 -3.21941553e-04 -3.35617951e-05 ...  1.89086488e-04
#    5.24493056e-05  4.93920895e-05]
#  [-3.21941553e-04  1.07071109e-02  2.43970421e-04 ... -1.45546385e-05
#    5.40969605e-05 -4.31088841e-05]
#  [-3.35617951e-05  2.43970421e-04  1.24679653e-02 ...  1.02394358e-04
#    4.23811711e-05  3.08731775e-04]
#  ...
#  [ 1.89086488e-04 -1.45546385e-05  1.02394358e-04 ...  1.95354467e-02
#    4.04539815e-03  6.15579226e-03]
#  [ 5.24493056e-05  5.40969605e-05  4.23811711e-05 ...  4.04539815e-03
#    1.42787277e-02  1.86204328e-03]
#  [ 4.93920895e-05 -4.31088841e-05  3.08731775e-04 ...  6.15579226e-03
#    1.86204328e-03  2.22372481e-02]]
# Number of Samples: 1406
#
# Class 4:
# Mean Vector:
# 0      0.273060
# 1     -0.012690
# 2     -0.105517
# 3     -0.983446
# 4     -0.934881
#          ...
# 556    0.013413
# 557   -0.033260
# 558   -0.706042
# 559    0.006140
# 560   -0.089532
# Length: 561, dtype: float64
# Covariance Matrix:
# [[ 1.17093091e-02 -6.55850443e-04 -1.04804945e-03 ... -6.63016110e-04
#    2.05942949e-04  6.33825891e-04]
#  [-6.55850443e-04  1.09602675e-02  6.58637124e-04 ...  2.76511786e-05
#   -1.43988051e-04 -6.75049139e-05]
#  [-1.04804945e-03  6.58637124e-04  1.21555762e-02 ... -1.22719687e-04
#    3.78190190e-04  4.52681102e-05]
#  ...
#  [-6.63016110e-04  2.76511786e-05 -1.22719687e-04 ...  5.53732411e-02
#   -1.95310089e-02 -2.34755220e-02]
#  [ 2.05942949e-04 -1.43988051e-04  3.78190190e-04 ... -1.95310089e-02
#    2.99908411e-02  1.14244362e-02]
#  [ 6.33825891e-04 -6.75049139e-05  4.52681102e-05 ... -2.34755220e-02
#    1.14244362e-02  3.23461867e-02]]
# Number of Samples: 1777
#
# Class 5:
# Mean Vector:
# 0      0.279153
# 1     -0.016152
# 2     -0.106587
# 3     -0.984435
# 4     -0.932509
#          ...
# 556    0.004614
# 557    0.015957
# 558   -0.774143
# 559    0.209818
# 560    0.031743
# Length: 561, dtype: float64
# Covariance Matrix:
# [[1.03692160e-02 2.14929948e-04 2.03601562e-04 ... 1.91575387e-04
#   6.82568488e-05 1.29124075e-04]
#  [2.14929948e-04 1.03625397e-02 2.95289956e-04 ... 7.84336139e-05
#   9.16950895e-05 3.14810217e-05]
#  [2.03601562e-04 2.95289956e-04 1.14267581e-02 ... 9.94335907e-05
#   2.81327822e-05 2.09464907e-04]
#  ...
#  [1.91575387e-04 7.84336139e-05 9.94335907e-05 ... 2.01038201e-02
#   5.52962164e-03 4.56873632e-03]
#  [6.82568488e-05 9.16950895e-05 2.81327822e-05 ... 5.52962164e-03
#   1.58010200e-02 1.30889771e-03]
#  [1.29124075e-04 3.14810217e-05 2.09464907e-04 ... 4.56873632e-03
#   1.30889771e-03 2.14693873e-02]]
# Number of Samples: 1906
#
# Class 6:
# Mean Vector:
# 0      0.268649
# 1     -0.018318
# 2     -0.107436
# 3     -0.960932
# 4     -0.943507
#          ...
# 556    0.022788
# 557    0.009191
# 558    0.520261
# 559   -0.435944
# 560   -0.427749
# Length: 561, dtype: float64
# Covariance Matrix:
# [[ 1.92730463e-02  1.66761008e-03 -4.01763382e-03 ...  1.60075642e-03
#    1.42152837e-04  5.53906299e-04]
#  [ 1.66761008e-03  1.40175933e-02 -1.77214513e-03 ... -8.23134723e-06
#    5.85024499e-04 -1.75421112e-04]
#  [-4.01763382e-03 -1.77214513e-03  1.60395290e-02 ... -6.03820376e-04
#    4.43881092e-04 -7.52591788e-04]
#  ...
#  [ 1.60075642e-03 -8.23134723e-06 -6.03820376e-04 ...  2.89549305e-02
#    8.82527600e-03 -3.95965629e-05]
#  [ 1.42152837e-04  5.85024499e-04  4.43881092e-04 ...  8.82527600e-03
#    1.22713690e-01 -3.35822642e-02]
#  [ 5.53906299e-04 -1.75421112e-04 -7.52591788e-04 ... -3.95965629e-05
#   -3.35822642e-02  1.33255456e-01]]
# Number of Samples: 1944

# %%
# def calculate_cov_matrix(features, regularization_parameter):
#     cov_matrix = np.cov(features, rowvar=False)
#     cov_matrix_regularized = cov_matrix + regularization_parameter * np.identity(cov_matrix.shape[0])
#     return cov_matrix_regularized

# regularization_parameter = 0.01  # 调整正则化参数的值
# class_stats = {}

# for label in class_labels:
#     class_data = data[data[561] == label]
#     features = class_data.iloc[:, :-1]
#     mean_vector = np.mean(features, axis=0)
#     cov_matrix_regularized = calculate_cov_matrix(features, regularization_parameter)
#     num_samples = len(class_data)
    
#     class_stats[label] = {
#         'mean_vector': mean_vector,
#         'cov_matrix': cov_matrix_regularized,
#         'num_samples': num_samples
#     }

# %%
def calculate_posterior(sample, mean_vector, cov_matrix, prior, num_samples):
    # 计算后验概率
    likelihood = (1 / ((2 * np.pi) ** (len(sample) / 2) * np.linalg.det(cov_matrix) ** 0.5)) * \
                np.exp(-0.5 * (sample - mean_vector).T @ np.linalg.inv(cov_matrix) @ (sample - mean_vector))
    posterior = likelihood * prior / (num_samples / N)
    return posterior

def bayesian_classifier(sample, class_stats):
    max_posterior = -1
    predicted_class = None
    
    for label, stats in class_stats.items():
        prior = stats['num_samples'] / N
        posterior = calculate_posterior(sample, stats['mean_vector'], stats['cov_matrix'], prior, stats['num_samples'])
        
        if posterior > max_posterior:
            max_posterior = posterior
            predicted_class = label
    
    return predicted_class

# 初始化变量以跟踪错误
total_samples = 0
total_errors = 0

# 对每个样本应用贝叶斯分类器
predicted_labels = []
for _, row in data.iterrows():
    
#     sample = row[:-1]  # 去掉最后一列（类别标签）
#     true_label = row[-1]  # 真实类别标签
    sample = row.iloc[:-1]  # 获取最后一列之前的数据
    true_label = row.iloc[-1]  # 获取最后一列的数据
    predicted_label = bayesian_classifier(sample, class_stats)
    predicted_labels.append(predicted_label)
    
    # 检查是否预测正确
    if true_label != predicted_label:
        total_errors += 1

    total_samples += 1

# 误差率估计
error_rate = total_errors / total_samples
print(f"Total errors: {total_errors}")
print(f"Error rate: {error_rate:.4f}")
# Out:
# /var/folders/vc/hp1kfbmj7lb7k9nhyd12slww0000gn/T/ipykernel_1927/1234798117.py:3: RuntimeWarning: divide by zero encountered in double_scalars
#   likelihood = (1 / ((2 * np.pi) ** (len(sample) / 2) * np.linalg.det(cov_matrix) ** 0.5)) * \
# /var/folders/vc/hp1kfbmj7lb7k9nhyd12slww0000gn/T/ipykernel_1927/1234798117.py:3: RuntimeWarning: invalid value encountered in double_scalars
#   likelihood = (1 / ((2 * np.pi) ** (len(sample) / 2) * np.linalg.det(cov_matrix) ** 0.5)) * \
# Total errors: 7091
# Error rate: 0.6885
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/vc/hp1kfbmj7lb7k9nhyd12slww0000gn/T/ipykernel_1927/1234798117.py in <module>
#      49
#      50 # 将预测结果与真实标签进行比较
# ---> 51 true_labels = data['quality'].tolist()
#      52 correct_predictions = np.sum(np.array(predicted_labels) == np.array(true_labels))
#      53 accuracy = correct_predictions / N
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     386                 except ValueError as err:
#     387                     raise KeyError(key) from err
# --> 388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#     390
#
# KeyError: 'quality'

# %%
# 将预测结果与真实标签进行比较
true_labels = data[561].tolist()
correct_predictions = np.sum(np.array(predicted_labels) == np.array(true_labels))
accuracy = correct_predictions / N

print(f"Accuracy: {accuracy:.2%}")
# Out:
# Accuracy: 31.15%

# %%
confusion_matrix = np.zeros((11, 11, 4), dtype=int)
print(confusion_matrix.shape)

for true_label, predicted_label in zip(true_labels, predicted_labels):
    if true_label == predicted_label:
        confusion_matrix[true_label, true_label, 0] += 1  # TP
    else:
        confusion_matrix[true_label, predicted_label, 1] += 1  # FP
        confusion_matrix[true_label, true_label, 2] += 1  # FN
        confusion_matrix[predicted_label, predicted_label, 3] += 1  # TN

# 打印混淆矩阵
print("Confusion Matrix:")
for true_label in class_labels:
    for predicted_label in class_labels:
        tp, fp, fn, tn = confusion_matrix[true_label, predicted_label]
        print(f"True Label {true_label} - Predicted Label {predicted_label}:")
        print(f"True Positives (TP): {tp}")
        print(f"False Positives (FP): {fp}")
        print(f"False Negatives (FN): {fn}")
        print(f"True Negatives (TN): {tn}")
        print()
# Out:
# (11, 11, 4)
# Confusion Matrix:
# True Label 1 - Predicted Label 1:
# True Positives (TP): 1722
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 3435
#
# True Label 1 - Predicted Label 2:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 1 - Predicted Label 3:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 1 - Predicted Label 4:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 1 - Predicted Label 5:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 1 - Predicted Label 6:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 2 - Predicted Label 1:
# True Positives (TP): 0
# False Positives (FP): 1544
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 2 - Predicted Label 2:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 1544
# True Negatives (TN): 379
#
# True Label 2 - Predicted Label 3:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 2 - Predicted Label 4:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 2 - Predicted Label 5:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 2 - Predicted Label 6:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 3 - Predicted Label 1:
# True Positives (TP): 0
# False Positives (FP): 1394
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 3 - Predicted Label 2:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 3 - Predicted Label 3:
# True Positives (TP): 12
# False Positives (FP): 0
# False Negatives (FN): 1394
# True Negatives (TN): 0
#
# True Label 3 - Predicted Label 4:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 3 - Predicted Label 5:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 3 - Predicted Label 6:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 4 - Predicted Label 1:
# True Positives (TP): 0
# False Positives (FP): 153
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 4 - Predicted Label 2:
# True Positives (TP): 0
# False Positives (FP): 169
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 4 - Predicted Label 3:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 4 - Predicted Label 4:
# True Positives (TP): 1455
# False Positives (FP): 0
# False Negatives (FN): 322
# True Negatives (TN): 3277
#
# True Label 4 - Predicted Label 5:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 4 - Predicted Label 6:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 5 - Predicted Label 1:
# True Positives (TP): 0
# False Positives (FP): 344
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 5 - Predicted Label 2:
# True Positives (TP): 0
# False Positives (FP): 206
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 5 - Predicted Label 3:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 5 - Predicted Label 4:
# True Positives (TP): 0
# False Positives (FP): 1356
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 5 - Predicted Label 5:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 1906
# True Negatives (TN): 0
#
# True Label 5 - Predicted Label 6:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 6 - Predicted Label 1:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 6 - Predicted Label 2:
# True Positives (TP): 0
# False Positives (FP): 4
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 6 - Predicted Label 3:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 6 - Predicted Label 4:
# True Positives (TP): 0
# False Positives (FP): 1921
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 6 - Predicted Label 5:
# True Positives (TP): 0
# False Positives (FP): 0
# False Negatives (FN): 0
# True Negatives (TN): 0
#
# True Label 6 - Predicted Label 6:
# True Positives (TP): 19
# False Positives (FP): 0
# False Negatives (FN): 1925
# True Negatives (TN): 0

# %%
####可视化
data_array = data.values
print(data_array)
# Out:
# [[ 0.28858451 -0.02029417 -0.13290514 ...  0.17994061 -0.05862692
#    5.        ]
#  [ 0.27841883 -0.01641057 -0.12352019 ...  0.18028889 -0.05431672
#    5.        ]
#  [ 0.27965306 -0.01946716 -0.11346169 ...  0.18063731 -0.04911782
#    5.        ]
#  ...
#  [ 0.34996609  0.03007744 -0.11578796 ...  0.27447878  0.18118355
#    2.        ]
#  [ 0.23759383  0.01846687 -0.09649893 ...  0.26478161  0.18756291
#    2.        ]
#  [ 0.15362719 -0.01843651 -0.13701846 ...  0.26393619  0.1881034
#    2.        ]]

# %%
# 绘制数据和两个附加数据点
import matplotlib.pyplot as plt


fig = plt.figure(0)

for label in class_labels:
    # 按类别筛选数据
    class_data = data[data[561] == label]
    if not class_data.empty:
        ax = fig.gca(projection='3d')
        class_data =class_data.values
        ax.scatter(class_data[:, 0], class_data[:, 1], class_data[:, 2],label=label)

# 添加图例
ax.legend()
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('X3')
plt.title('Class 0 and Class 1 True Class Labels')
plt.show()
